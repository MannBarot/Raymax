# %%
from reachy_sdk import ReachySDK
from gtts import gTTS
import pygame
import socket
import io
import sounddevice as sd
import numpy as np
import scipy.io.wavfile as wav
import whisper
import numpy as np
from google import genai
from pydub import AudioSegment
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/reachy/.local/lib/python3.10/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
#SPEAK function

def speak(text, lang='en', speed = 1.3): #speed = 1 is default
    tts = gTTS(text=text, lang=lang)
    buf = io.BytesIO()
    tts.write_to_fp(buf)
    buf.seek(0)
    
    pygame.mixer.init()
    pygame.mixer.music.load(buf, 'mp3')
    pygame.mixer.music.set_volume(1.5)  # 0.0 to 1.0
    pygame.mixer.music.play()
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)
        
        # tts = gTTS(
#     text="Hello, I am Reachy",
#     lang='en',        # language
#     tld='co.uk',      # accent! com - US English (default), co.uk - British, com.au- Australian,ca- Canadian,co.in- Indian
#     slow=False        # slow mode for clarity
# )

# %%
import sounddevice as sd

def get_respeaker_index():
    for i, dev in enumerate(sd.query_devices()):
        if 'ReSpeaker' in dev['name']:
            return i
    raise RuntimeError("ReSpeaker not found!")
DEVICE_INDEX = get_respeaker_index()  # dynamically finds ReSpeaker


print(f"DEVICE_INDEX: {DEVICE_INDEX}")
print(f"CHANNELS: {CHANNELS}")

SAMPLE_RATE = 16000
DEVICE_INDEX = 6
CHANNELS = 4
CHUNK_SIZE = 1024
SILENCE_THRESHOLD = 300    # adjust based on environment
SILENCE_DURATION = 1.5     # seconds of silence before stopping
MIN_SPEECH_DURATION = 0.5  # ignore very short sounds (coughs, clicks)

def record_until_silence():
    print("Listening...")
    chunks = []
    silent_chunks = 0
    speech_chunks = 0
    max_silent_chunks = int((SILENCE_DURATION * SAMPLE_RATE) / CHUNK_SIZE)
    min_speech_chunks = int((MIN_SPEECH_DURATION * SAMPLE_RATE) / CHUNK_SIZE)
    started_speaking = False

    with sd.InputStream(samplerate=SAMPLE_RATE, channels=CHANNELS,
                        dtype='int16', device=DEVICE_INDEX,
                        blocksize=CHUNK_SIZE) as stream:
        while True:
            chunk, _ = stream.read(CHUNK_SIZE)
            volume = np.abs(chunk[:, 0]).mean()  # use channel 0

            if volume > SILENCE_THRESHOLD:
                started_speaking = True
                silent_chunks = 0
                speech_chunks += 1
                chunks.append(chunk[:, 0])
            elif started_speaking:
                chunks.append(chunk[:, 0])
                silent_chunks += 1
                if silent_chunks >= max_silent_chunks:
                    # only accept if speech was long enough
                    if speech_chunks >= min_speech_chunks:
                        break
                    else:
                        # too short, reset and keep listening
                        chunks = []
                        silent_chunks = 0
                        speech_chunks = 0
                        started_speaking = False

    print("Done.")
    return np.concatenate(chunks, axis=0)
# Out:
# DEVICE_INDEX: 6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_288783/3965175254.py in <module>
#      10
#      11 print(f"DEVICE_INDEX: {DEVICE_INDEX}")
# ---> 12 print(f"CHANNELS: {CHANNELS}")
#      13
#      14 SAMPLE_RATE = 16000
#
# NameError: name 'CHANNELS' is not defined

# %%
#Setup Whisper STT/ transcribe method
# import whisper
# import numpy as np

model = whisper.load_model("base")  # loads once

def transcribe(audio):
    # convert from int16 to float32 that whisper expects
    audio_float = audio.astype(np.float32) / 32768.0
    audio_flat = audio_float.flatten()  # whisper expects 1D array
    result = model.transcribe(audio_flat, fp16=False)
    return result["text"]

# %%
#Setting up Gemini LLM

instruction = f"""You are Reachy, a friendly humanoid robot being used for medical triage research in the IRON lab at the
 University of North Carolina at Chapel Hill. Keep responses short and conversational.Do not use emojis or special characters
in your responses."""

from google.genai import types
client = genai.Client(api_key="AIzaSyAvQb9HBliQQxgEsQbFnuPqZKKFD6blIXU")

chat_session = client.chats.create(
    model="gemini-2.5-flash-lite",
    config=types.GenerateContentConfig(
        system_instruction= instruction
    )
)

def chat(user_input):
    response = chat_session.send_message(user_input)
    return response.text

# %%
# Full loop for talking back and forth
while True:
    audio = record_until_silence()
    text = transcribe(audio)
    print(f"You: {text}")

    reply = chat(text)
    print(f"Reachy: {reply}")

    speak(reply)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_278460/3576796542.py in <module>
#       1 # Full loop for talking back and forth
#       2 while True:
# ----> 3     audio = record_until_silence()
#       4     text = transcribe(audio)
#       5     print(f"You: {text}")
#
# NameError: name 'record_until_silence' is not defined

# %%
#face tracking test
import asyncio
from reachy_face_tracking.face_tracking_background import FaceTrackingBackground

async def face_tracking_loop(ft):
    ft.detection.start()
    ft.activate_tracking_mode()
    print("Face tracking started...")
    
    try:
        while True:
            if ft.detection._somebody_detected:
                ft.get_target_info()
                ft.track()
            await asyncio.sleep(0.02)
    except asyncio.CancelledError:
        print("Face tracking stopped.")
        ft.deactivate_tracking_mode()
        ft.detection.stop()

async def main():
    with FaceTrackingBackground(host='localhost') as ft:
        await ft.setup()
        
        # Start face tracking in background
        tracking_task = asyncio.ensure_future(face_tracking_loop(ft))
        
        # Do other things while tracking runs...
        print("Waiting 5 seconds...")
        await asyncio.sleep(5)
        
        # Stop tracking whenever you're ready
        tracking_task.cancel()
        await tracking_task  # wait for clean shutdown

await main()

# The key idea is asyncio.ensure_future() launches the tracking loop as a background task, 
# and tracking_task.cancel() stops it cleanly whenever you want — after 5 seconds here, 
# but you could trigger it from anywhere, like after a voice command is detected.
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /tmp/ipykernel_95708/3311259352.py in <module>
#      34         await tracking_task  # wait for clean shutdown
#      35
# ---> 36 await main()
#      37
#      38 # The key idea is asyncio.ensure_future() launches the tracking loop as a background task,
#
# /tmp/ipykernel_95708/3311259352.py in main()
#      20
#      21 async def main():
# ---> 22     with FaceTrackingBackground(host='localhost') as ft:
#      23         await ft.setup()
#      24
#
# ~/dev/reachy-face-tracking/reachy_face_tracking/face_tracking_background.py in __init__(self, host)
#      23     """
#      24     def __init__(self, host: str = 'localhost'):
# ---> 25         self.reachy = ReachySDK(host=host)
#      26
#      27         self.prev_y, self.prev_z = 0, 0
#
# ...

# %%
#test_face_tracking()
# Out:
# <coroutine object test_face_tracking at 0x7f49ef578660>

# %%
#MIC TEST
import sounddevice as sd
# import numpy as np
# import scipy.io.wavfile as wav

# ReSpeaker device is No. 6. Use this to double check
print(sd.query_devices())
# Out:
#    0 HDA Intel PCH: HDMI 0 (hw:0,3), ALSA (0 in, 8 out)
#    1 HDA Intel PCH: HDMI 1 (hw:0,7), ALSA (0 in, 8 out)
#    2 HDA Intel PCH: HDMI 2 (hw:0,8), ALSA (0 in, 8 out)
#    3 HDA Intel PCH: HDMI 3 (hw:0,9), ALSA (0 in, 8 out)
#    4 HDA Intel PCH: HDMI 4 (hw:0,10), ALSA (0 in, 8 out)
#    5 C2: USB Audio (hw:1,0), ALSA (2 in, 0 out)
#    6 ReSpeaker 4 Mic Array (UAC1.0): USB Audio (hw:2,0), ALSA (6 in, 2 out)
#    7 C2: USB Audio (hw:3,0), ALSA (2 in, 0 out)
#    8 hdmi, ALSA (0 in, 8 out)
#    9 pulse, ALSA (32 in, 32 out)
# * 10 default, ALSA (32 in, 32 out)

# %%
#yell out its IP
#import socket

def get_ip():
    s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
    try:
        s.connect(("8.8.8.8", 80))  # doesn't actually send data
        return s.getsockname()[0]
    finally:
        s.close()

print(get_ip())
# Out:
# 152.23.165.203

# %%
# Speaking TEST
speak("Hello, how are you today")

# %%
sd.play(audio, SAMPLE_RATE)
sd.wait()

# %%
DEVICE_INDEX = 0   # ReSpeaker's index from list of devices
SAMPLE_RATE = 16000
DURATION =  5      # seconds
CHANNELS = 6  # ReSpeaker has 4 mics

def record(duration=DURATION):
    print("Recording...")
    audio = sd.rec(
        int(duration * SAMPLE_RATE),
        samplerate=SAMPLE_RATE,
        channels=CHANNELS,
        dtype='int16',
        device=DEVICE_INDEX
    )
    sd.wait()
    print("Done.")
    return audio[:, 0]  # take only channel 0 (already beamformed by DSP)

#audio = record()

# %%
#STT
#audio = record()
#text = transcribe(audio)
#print(text)
#speak(text)

# %%
#new speak
# import edge_tts
# import asyncio
# import io
# import pygame

# async def _synthesize(text, voice):
#     buf = io.BytesIO()
#     communicate = edge_tts.Communicate(text, voice=voice)
#     async for chunk in communicate.stream():
#         if chunk["type"] == "audio":
#             buf.write(chunk["data"])
#     buf.seek(0)
#     return buf

# async def speak(text, voice="en-US-GuyNeural", speed=1.3):
#     buf = await _synthesize(text, voice)
    
#     audio = AudioSegment.from_mp3(buf)
#     fast_audio = audio._spawn(audio.raw_data, overrides={
#         "frame_rate": int(audio.frame_rate * speed)
#     }).set_frame_rate(audio.frame_rate)
    
#     out = io.BytesIO()
#     fast_audio.export(out, format='mp3')
#     out.seek(0)
    
#     pygame.mixer.init()
#     pygame.mixer.music.load(out, 'mp3')
#     pygame.mixer.music.play()
#     while pygame.mixer.music.get_busy():
#         pygame.time.Clock().tick(10)
