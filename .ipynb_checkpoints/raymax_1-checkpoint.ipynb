# %%
from reachy_sdk import ReachySDK

reachy = ReachySDK(host='localhost')  # Replace with the actual IP using reachy = ReachySDK(host='192.168.0.42')

# %%
#OpenCV demo
import cv2 as cv

while True:
    # This let you access the last frame grabbed by Reachy left eye
    # It's always the most up-to-date image
    left_image = reachy.left_camera.last_frame

    cv.imshow('left image', left_image)

# %%
#required imports for Audio
import time
#from reachyAudio import reachyAudio
from ReachyAudio import reachyAudio
#from reachy import Reachy, parts

# %%
#Audio Testing
from ReachyAudio.reachyAudio import reachyAudio
from ReachyAudio.reachyAudio import reachyAudioTextToSpeech
#reachy_audio = reachyAudio.ReachyAudio()
reachy_audio = reachyAudio.reachyAudioTextToSpeech()
reachy = Reachy(head=parts.Head(io='/dev/ttyUSB*'),)

#text to speech test
reachy_audio.speak("Hello there, my name is Reachy")
# Out:
# C:\Users\mannb\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydub\utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# C:\Users\mannb\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydub\utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# C:\Users\mannb\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydub\utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# C:\Users\mannb\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydub\utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ...
