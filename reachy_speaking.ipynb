# %%
from reachy_sdk import ReachySDK
from findIP import get_reachy_ip
# ~/dev/reachy-sdk
#reachy = ReachySDK(host='localhost')

reachy_ip = get_reachy_ip()
reachy = ReachySDK(host=reachy_ip)# Replace with the actual IP using reachy = ReachySDK(host='192.168.0.42')
# Out:
# Reachy's IP address: 172.18.78.99
# Environment variable REACHY_IP set.

# %%
#Required imports for Audio


import time
#from reachyAudio import reachyAudio

#from reachy import Reachy, parts

# %%
#Audio Testing

import sys
import os

# Add the ReachyAudio folder to the Python path
sys.path.append(os.path.abspath('../ReachyAudio'))

from reachyAudio import reachyAudio

#from reachyAudio import reachyAudio


reachy_audio = reachyAudio.ReachyAudio()
#reachy = Reachy(head=parts.Head(io='/dev/ttyUSB*'),)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/reachy/.local/lib/python3.10/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_56068/1564066962.py in <module>
#       7 sys.path.append(os.path.abspath('../ReachyAudio'))
#       8
# ----> 9 from reachyAudio import reachyAudio
#      10
#      11 #from reachyAudio import reachyAudio
#
# ~/Mann/ReachyAudio/reachyAudio/reachyAudio.py in <module>
# ...

# %%
#text to speech test
#best voices are: English (America),
reachy_audio.setEngineProperties(130, 1)
reachy_audio.

# %%
#speaking input
#reachy_audio.speak("Reachy")
reachy_audio.speak("My name is richy")

# %%
#Top commands:
reachy_audio.availableVoices()
# Out:
# Voice:
#  - ID: Afrikaans
#  - Name: Afrikaans
#  - Gender: male
# Voice:
#  - ID: Amharic
#  - Name: Amharic
#  - Gender: male
# Voice:
#  - ID: Aragonese
#  - Name: Aragonese
#  - Gender: male
# Voice:
#  - ID: Arabic
#  - Name: Arabic
#  - Gender: male
# Voice:
#  - ID: Assamese
#  - Name: Assamese
#  - Gender: male
# Voice:
#  - ID: Azerbaijani
#  - Name: Azerbaijani
#  - Gender: male
# Voice:
#  - ID: Bashkir
#  - Name: Bashkir
#  - Gender: male
# Voice:
#  - ID: Bulgarian
#  - Name: Bulgarian
#  - Gender: male
# Voice:
#  - ID: Bengali
#  - Name: Bengali
#  - Gender: male
# Voice:
#  - ID: Bishnupriya Manipuri
#  - Name: Bishnupriya Manipuri
#  - Gender: male
# Voice:
#  - ID: Bosnian
#  - Name: Bosnian
#  - Gender: male
# Voice:
#  - ID: Catalan
#  - Name: Catalan
#  - Gender: male
# Voice:
#  - ID: Chinese (Mandarin)
#  - Name: Chinese (Mandarin)
#  - Gender: male
# Voice:
#  - ID: Czech
#  - Name: Czech
#  - Gender: male
# Voice:
#  - ID: Welsh
#  - Name: Welsh
# ...

# %%
said = reachy_audio.recognizeSpeech()

print(said)
if "name" in said:
    reachy_audio.speak("My name is Richy")
# Out:
# ALSA lib pcm_dsnoop.c:601:(snd_pcm_dsnoop_open) unable to open slave
# ALSA lib pcm_dmix.c:1032:(snd_pcm_dmix_open) unable to open slave
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib pcm_oss.c:397:(_snd_pcm_oss_open) Cannot open device /dev/dsp
# ALSA lib pcm_oss.c:397:(_snd_pcm_oss_open) Cannot open device /dev/dsp
# ALSA lib confmisc.c:160:(snd_config_get_card) Invalid field card
# ALSA lib pcm_usb_stream.c:482:(_snd_pcm_usb_stream_open) Invalid card 'card'
# ALSA lib confmisc.c:160:(snd_config_get_card) Invalid field card
# ALSA lib pcm_usb_stream.c:482:(_snd_pcm_usb_stream_open) Invalid card 'card'
# ALSA lib pcm_dmix.c:1032:(snd_pcm_dmix_open) unable to open slave
# Say something
# ---------------------------------------------------------------------------
# ...

# %%
recorded = reachy_audio.recordAudio(5, "test1.wav")
# Out:
# ALSA lib pcm_dsnoop.c:601:(snd_pcm_dsnoop_open) unable to open slave
# ALSA lib pcm_dmix.c:1032:(snd_pcm_dmix_open) unable to open slave
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib pcm_oss.c:397:(_snd_pcm_oss_open) Cannot open device /dev/dsp
# ALSA lib pcm_oss.c:397:(_snd_pcm_oss_open) Cannot open device /dev/dsp
# ALSA lib confmisc.c:160:(snd_config_get_card) Invalid field card
# ALSA lib pcm_usb_stream.c:482:(_snd_pcm_usb_stream_open) Invalid card 'card'
# ALSA lib confmisc.c:160:(snd_config_get_card) Invalid field card
# ALSA lib pcm_usb_stream.c:482:(_snd_pcm_usb_stream_open) Invalid card 'card'
# ALSA lib pcm_dmix.c:1032:(snd_pcm_dmix_open) unable to open slave
# * recording
# * done recording

# %%
print(reachy_audio.mic.is_voice())
# Out:
# Exception in callback PollerCompletionQueue._handle_events(<_UnixSelecto...e debug=False>)()
# handle: <Handle PollerCompletionQueue._handle_events(<_UnixSelecto...e debug=False>)()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "src/python/grpcio/grpc/_cython/_cygrpc/aio/completion_queue.pyx.pxi", line 147, in grpc._cython.cygrpc.PollerCompletionQueue._handle_events
# BlockingIOError: [Errno 11] Resource temporarily unavailable
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_68949/1791971814.py in <module>
# ----> 1 print(reachy_audio.mic.is_voice())
#
# ~/Mann/Raymax/ReachyAudio/utils/tuning.py in is_voice(self)
#     126
#     127     def is_voice(self):
# --> 128         return self.read('VOICEACTIVITY')
#     129
#     130     @property
# ...
